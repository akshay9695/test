# %%
import pandas as pd

# %%
df = pd.read_csv('sales_data_final.csv')

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
type(df['order_id'])
# Out:
# pandas.core.series.Series

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df['profit']
# Out:
# 0        106.1400
# 1         36.0360
# 2         29.6400
# 3        -26.0550
# 4         37.7700
#            ...
# 51285      4.5188
# 51286      0.4200
# 51287     12.3600
# 51288      0.5600
# 51289     -0.6048
# Name: profit, Length: 51290, dtype: float64

# %%
df[['profit', 'market', 'year']]
# Out:
#          profit  market  year
# 0      106.1400  Africa  2011
# 1       36.0360    APAC  2011
# 2       29.6400    EMEA  2011
# 3      -26.0550      EU  2011
# 4       37.7700    APAC  2011
# ...         ...     ...   ...
# 51285    4.5188      US  2014
# 51286    0.4200  Africa  2014
# 51287   12.3600   LATAM  2014
# 51288    0.5600   LATAM  2014
# 51289   -0.6048      US  2014
#
# [51290 rows x 3 columns]

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df[['order_id', 'product_id', 'quantity'] ]
# Out:
#               order_id        product_id  quantity
# 0         AG-2011-2040  OFF-TEN-10000025         2
# 1        IN-2011-47883   OFF-SU-10000618         3
# 2         HU-2011-1220  OFF-TEN-10001585         4
# 3      IT-2011-3647632   OFF-PA-10001492         3
# 4        IN-2011-47883   FUR-FU-10003447         5
# ...                ...               ...       ...
# 51285   CA-2014-115427   OFF-BI-10002103         2
# 51286     MO-2014-2560  OFF-WIL-10001069         1
# 51287   MX-2014-110527   OFF-LA-10004182         3
# 51288   MX-2014-114783   OFF-LA-10000413         1
# 51289   CA-2014-156720   OFF-FA-10003472         3
#
# [51290 rows x 3 columns]

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# 0  Office Supplies      Storage          Tenex Lockers, Blue   408        2
# 1  Office Supplies     Supplies     Acme Trimmer, High Speed   120        3
# 2  Office Supplies      Storage      Tenex Box, Single Width    66        4
# 3  Office Supplies        Paper  Enermax Note Cards, Premium    45        3
# 4        Furniture  Furnishings   Eldon Light Bulb, Duo Pack   114        5
#
#    discount   profit  shipping_cost  order_priority  year
# 0       0.0  106.140          35.46          Medium  2011
# 1       0.1   36.036           9.72          Medium  2011
# 2       0.0   29.640           8.17            High  2011
# 3       0.5  -26.055           4.82            High  2011
# 4       0.1   37.770           4.70          Medium  2011
#
# [5 rows x 21 columns]

# %%
df.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df.dtypes == 'object'
# Out:
# order_id           True
# order_date         True
# ship_date          True
# ship_mode          True
# customer_name      True
# segment            True
# state              True
# country            True
# market             True
# region             True
# product_id         True
# category           True
# sub_category       True
# product_name       True
# sales              True
# quantity          False
# discount          False
# profit            False
# shipping_cost     False
# order_priority     True
# year              False
# dtype: bool

# %%
type(df.dtypes[df.dtypes == 'object'])
# Out:
# pandas.core.series.Series

# %%
df[df.dtypes[df.dtypes == 'object'].index].describe()
# Out:
#               order_id order_date   ship_date       ship_mode  \
# count            51290      51290       51290           51290
# unique           25035       1430        1464               4
# top     CA-2014-100111  6/18/2014  11/22/2014  Standard Class
# freq                14        135         130           30775
#
#           customer_name   segment       state        country market   region  \
# count             51290     51290       51290          51290  51290    51290
# unique              795         3        1094            147      7       13
# top     Muhammed Yedwab  Consumer  California  United States   APAC  Central
# freq                108     26518        2001           9994  11002    11117
#
#              product_id         category sub_category product_name  sales  \
# count             51290            51290        51290        51290  51290
# unique            10292                3           17         3788   2246
# top     OFF-AR-10003651  Office Supplies      Binders      Staples     13
# freq                 35            31273         6152          227    589
#
#        order_priority
# count           51290
# unique              4
# top            Medium
# freq            29433

# %%
df[df.dtypes[df.dtypes == 'float64'].index].describe()
# Out:
#            discount        profit  shipping_cost
# count  51290.000000  51290.000000   51290.000000
# mean       0.142908     28.641740      26.375915
# std        0.212280    174.424113      57.296804
# min        0.000000  -6599.978000       0.000000
# 25%        0.000000      0.000000       2.610000
# 50%        0.000000      9.240000       7.790000
# 75%        0.200000     36.810000      24.450000
# max        0.850000   8399.976000     933.570000

# %%
df['order_id'][1:44:3]
# Out:
# 1       IN-2011-47883
# 4       IN-2011-47883
# 7       IN-2011-79397
# 10      IN-2011-65159
# 13      IN-2011-33652
# 16        IR-2011-770
# 19      ID-2011-12596
# 22        IR-2011-770
# 25      IN-2011-65159
# 28     MX-2011-140641
# 31     MX-2011-111255
# 34     MX-2011-159373
# 37    IT-2011-2942451
# 40    IT-2011-2942451
# 43     MX-2011-109267
# Name: order_id, dtype: object

# %%
df['category1'] = 'akki'

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... sub_category  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      Storage
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...     Supplies
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      Storage
# 3  Home Office        Stockholm     Sweden      EU    North  ...        Paper
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...  Furnishings
#
#                   product_name sales quantity discount   profit  \
# 0          Tenex Lockers, Blue   408        2      0.0  106.140
# 1     Acme Trimmer, High Speed   120        3      0.1   36.036
# 2      Tenex Box, Single Width    66        4      0.0   29.640
# 3  Enermax Note Cards, Premium    45        3      0.5  -26.055
# 4   Eldon Light Bulb, Duo Pack   114        5      0.1   37.770
#
#    shipping_cost  order_priority  year category1
# 0          35.46          Medium  2011      akki
# 1           9.72          Medium  2011      akki
# 2           8.17            High  2011      akki
# 3           4.82            High  2011      akki
# 4           4.70          Medium  2011      akki
#
# [5 rows x 22 columns]

# %%
df['state'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 51285    False
# 51286    False
# 51287    False
# 51288    False
# 51289    False
# Name: state, Length: 51290, dtype: bool

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1'],
#       dtype='object')

# %%
df[df['profit'] == max(df['profit'])]['customer_name']
# Out:
# 29530    Tamara Chand
# Name: customer_name, dtype: object

# %%
df[df['profit'] == min(df['profit'])]['customer_name']
# Out:
# 31884    Cindy Stewart
# Name: customer_name, dtype: object

# %%
len(df[df['country'] == 'Sweden']) # how many order rcivd from sweden
# Out:
# 203

# %%
df[df['shipping_cost'] > 80] ['country']
# Out:
# 7          Australia
# 8        New Zealand
# 9               Iraq
# 27            Brazil
# 43            Mexico
#             ...
# 51154      Indonesia
# 51228         Brazil
# 51229      Indonesia
# 51230         Russia
# 51231       Thailand
# Name: country, Length: 3984, dtype: object

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... sub_category  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      Storage
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...     Supplies
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      Storage
# 3  Home Office        Stockholm     Sweden      EU    North  ...        Paper
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...  Furnishings
#
#                   product_name sales quantity discount   profit  \
# 0          Tenex Lockers, Blue   408        2      0.0  106.140
# 1     Acme Trimmer, High Speed   120        3      0.1   36.036
# 2      Tenex Box, Single Width    66        4      0.0   29.640
# 3  Enermax Note Cards, Premium    45        3      0.5  -26.055
# 4   Eldon Light Bulb, Duo Pack   114        5      0.1   37.770
#
#    shipping_cost  order_priority  year category1
# 0          35.46          Medium  2011      akki
# 1           9.72          Medium  2011      akki
# 2           8.17            High  2011      akki
# 3           4.82            High  2011      akki
# 4           4.70          Medium  2011      akki
#
# [5 rows x 22 columns]

# %%
df[(df['shipping_cost']>80) &( df['profit'] < 10)]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 200    ES-2011-1374122   1/15/2011   1/18/2011     First Class
# 257     MX-2011-146584   1/21/2011   1/27/2011  Standard Class
# 341      ID-2011-36011   1/26/2011   1/27/2011     First Class
# 451    ES-2011-1640672    2/2/2011    2/5/2011     First Class
# ...                ...         ...         ...             ...
# 50970  ES-2014-4296634  12/27/2014    1/2/2015  Standard Class
# 51034    ID-2014-68183  12/29/2014  12/31/2014     First Class
# 51037  IT-2014-2245117  12/29/2014  12/31/2014     First Class
# 51153    ID-2014-51509  12/30/2014    1/1/2015    Second Class
# 51231    IN-2014-30390  12/31/2014    1/3/2015     First Class
#
#           customer_name      segment                         state  \
# 8          Ken Lonsdale     Consumer                      Auckland
# 200        Craig Leslie  Home Office            Nord-Pas-de-Calais
# 257        Hunter Lopez     Consumer                       Managua
# 341    Heather Kirkland    Corporate                    Jawa Barat
# 451          Ken Heidel    Corporate                        Saxony
# ...                 ...          ...                           ...
# 50970       Harry Marie    Corporate                      Brittany
# 51034         Adam Hart    Corporate                      Victoria
# 51037        Sarah Bern     Consumer                 North Holland
# 51153      Naresj Patel     Consumer  Australian Capital Territory
# 51231  Justin Deggeller    Corporate                       Bangkok
#
#            country market          region  ... sub_category  \
# 8      New Zealand   APAC         Oceania  ...      Copiers
# 200         France     EU         Central  ...    Bookcases
# 257      Nicaragua  LATAM         Central  ...       Tables
# 341      Indonesia   APAC  Southeast Asia  ...       Chairs
# 451        Germany     EU         Central  ...       Phones
# ...            ...    ...             ...  ...          ...
# 50970       France     EU         Central  ...   Appliances
# 51034    Australia   APAC         Oceania  ...   Appliances
# 51037  Netherlands     EU         Central  ...       Chairs
# 51153    Australia   APAC         Oceania  ...       Chairs
# 51231     Thailand   APAC  Southeast Asia  ...       Tables
#
#                                        product_name  sales quantity discount  \
# 8                       Hewlett Wireless Fax, Laser    912        4     0.40
# 200           Dania Library with Doors, Traditional    652        2     0.10
# 257    Chromcraft Conference Table, Fully Assembled  2,797        6     0.20
# 341       Novimex Executive Leather Armchair, Black    334        1     0.27
# 451               Motorola Signal Booster, Cordless    584        8     0.50
# ...                                             ...    ...      ...      ...
# 50970               Hamilton Beach Microwave, White  1,010        4     0.10
# 51034                             Hoover Stove, Red  1,535        3     0.10
# 51037                  Novimex Rocking Chair, Black    516        8     0.50
# 51153        Harbour Creations Rocking Chair, Black    434        5     0.40
# 51231       Lesro Training Table, Adjustable Height  1,049        9     0.57
#
#           profit  shipping_cost  order_priority  year category1
# 8      -319.4640         107.10             Low  2011      akki
# 200       7.2000          88.52          Medium  2011      akki
# 257      -0.0720         320.38             Low  2011      akki
# 341    -109.9365          92.67            High  2011      akki
# 451     -58.5600         109.14            High  2011      akki
# ...          ...            ...             ...   ...       ...
# 50970   -44.9400         108.27             Low  2014      akki
# 51034  -102.4110         255.42          Medium  2014      akki
# 51037  -392.1600          91.67        Critical  2014      akki
# 51153  -166.4700         124.63        Critical  2014      akki
# 51231 -1195.2387          86.86            High  2014      akki
#
# [843 rows x 22 columns]

# %%
df[(df['shipping_cost'] > 80 )& (df['profit'] < 10)]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 200    ES-2011-1374122   1/15/2011   1/18/2011     First Class
# 257     MX-2011-146584   1/21/2011   1/27/2011  Standard Class
# 341      ID-2011-36011   1/26/2011   1/27/2011     First Class
# 451    ES-2011-1640672    2/2/2011    2/5/2011     First Class
# ...                ...         ...         ...             ...
# 50970  ES-2014-4296634  12/27/2014    1/2/2015  Standard Class
# 51034    ID-2014-68183  12/29/2014  12/31/2014     First Class
# 51037  IT-2014-2245117  12/29/2014  12/31/2014     First Class
# 51153    ID-2014-51509  12/30/2014    1/1/2015    Second Class
# 51231    IN-2014-30390  12/31/2014    1/3/2015     First Class
#
#           customer_name      segment                         state  \
# 8          Ken Lonsdale     Consumer                      Auckland
# 200        Craig Leslie  Home Office            Nord-Pas-de-Calais
# 257        Hunter Lopez     Consumer                       Managua
# 341    Heather Kirkland    Corporate                    Jawa Barat
# 451          Ken Heidel    Corporate                        Saxony
# ...                 ...          ...                           ...
# 50970       Harry Marie    Corporate                      Brittany
# 51034         Adam Hart    Corporate                      Victoria
# 51037        Sarah Bern     Consumer                 North Holland
# 51153      Naresj Patel     Consumer  Australian Capital Territory
# 51231  Justin Deggeller    Corporate                       Bangkok
#
#            country market          region  ... sub_category  \
# 8      New Zealand   APAC         Oceania  ...      Copiers
# 200         France     EU         Central  ...    Bookcases
# 257      Nicaragua  LATAM         Central  ...       Tables
# 341      Indonesia   APAC  Southeast Asia  ...       Chairs
# 451        Germany     EU         Central  ...       Phones
# ...            ...    ...             ...  ...          ...
# 50970       France     EU         Central  ...   Appliances
# 51034    Australia   APAC         Oceania  ...   Appliances
# 51037  Netherlands     EU         Central  ...       Chairs
# 51153    Australia   APAC         Oceania  ...       Chairs
# 51231     Thailand   APAC  Southeast Asia  ...       Tables
#
#                                        product_name  sales quantity discount  \
# 8                       Hewlett Wireless Fax, Laser    912        4     0.40
# 200           Dania Library with Doors, Traditional    652        2     0.10
# 257    Chromcraft Conference Table, Fully Assembled  2,797        6     0.20
# 341       Novimex Executive Leather Armchair, Black    334        1     0.27
# 451               Motorola Signal Booster, Cordless    584        8     0.50
# ...                                             ...    ...      ...      ...
# 50970               Hamilton Beach Microwave, White  1,010        4     0.10
# 51034                             Hoover Stove, Red  1,535        3     0.10
# 51037                  Novimex Rocking Chair, Black    516        8     0.50
# 51153        Harbour Creations Rocking Chair, Black    434        5     0.40
# 51231       Lesro Training Table, Adjustable Height  1,049        9     0.57
#
#           profit  shipping_cost  order_priority  year category1
# 8      -319.4640         107.10             Low  2011      akki
# 200       7.2000          88.52          Medium  2011      akki
# 257      -0.0720         320.38             Low  2011      akki
# 341    -109.9365          92.67            High  2011      akki
# 451     -58.5600         109.14            High  2011      akki
# ...          ...            ...             ...   ...       ...
# 50970   -44.9400         108.27             Low  2014      akki
# 51034  -102.4110         255.42          Medium  2014      akki
# 51037  -392.1600          91.67        Critical  2014      akki
# 51153  -166.4700         124.63        Critical  2014      akki
# 51231 -1195.2387          86.86            High  2014      akki
#
# [843 rows x 22 columns]

# %%
df[(df['shipping_cost'] > 100) & (df['profit'] < 10)]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 257     MX-2011-146584   1/21/2011   1/27/2011  Standard Class
# 451    ES-2011-1640672    2/2/2011    2/5/2011     First Class
# 625      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# 626      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# ...                ...         ...         ...             ...
# 50781   CA-2014-147956  12/25/2014    1/1/2015  Standard Class
# 50969   US-2014-120166  12/27/2014  12/31/2014  Standard Class
# 50970  ES-2014-4296634  12/27/2014    1/2/2015  Standard Class
# 51034    ID-2014-68183  12/29/2014  12/31/2014     First Class
# 51153    ID-2014-51509  12/30/2014    1/1/2015    Second Class
#
#               customer_name    segment                         state  \
# 8              Ken Lonsdale   Consumer                      Auckland
# 257            Hunter Lopez   Consumer                       Managua
# 451              Ken Heidel  Corporate                        Saxony
# 625    Christopher Martinez   Consumer              National Capital
# 626    Christopher Martinez   Consumer              National Capital
# ...                     ...        ...                           ...
# 50781            Alan Hwang   Consumer                    Washington
# 50969          Frank Hawley  Corporate               Valle del Cauca
# 50970           Harry Marie  Corporate                      Brittany
# 51034             Adam Hart  Corporate                      Victoria
# 51153          Naresj Patel   Consumer  Australian Capital Territory
#
#              country market          region  ... sub_category  \
# 8        New Zealand   APAC         Oceania  ...      Copiers
# 257        Nicaragua  LATAM         Central  ...       Tables
# 451          Germany     EU         Central  ...       Phones
# 625      Philippines   APAC  Southeast Asia  ...       Phones
# 626      Philippines   APAC  Southeast Asia  ...      Copiers
# ...              ...    ...             ...  ...          ...
# 50781  United States     US            West  ...      Storage
# 50969       Colombia  LATAM           South  ...       Tables
# 50970         France     EU         Central  ...   Appliances
# 51034      Australia   APAC         Oceania  ...   Appliances
# 51153      Australia   APAC         Oceania  ...       Chairs
#
#                                             product_name  sales quantity  \
# 8                            Hewlett Wireless Fax, Laser    912        4
# 257         Chromcraft Conference Table, Fully Assembled  2,797        6
# 451                    Motorola Signal Booster, Cordless    584        8
# 625                 Nokia Signal Booster, with Caller ID    921        9
# 626                      Brother Fax Machine, High-Speed  1,235        6
# ...                                                  ...    ...      ...
# 50781  Office Impressions Heavy Duty Welded Shelving ...  1,004        6
# 50969               Barricks Training Table, Rectangular    842        5
# 50970                    Hamilton Beach Microwave, White  1,010        4
# 51034                                  Hoover Stove, Red  1,535        3
# 51153             Harbour Creations Rocking Chair, Black    434        5
#
#       discount   profit  shipping_cost  order_priority  year category1
# 8         0.40 -319.464         107.10             Low  2011      akki
# 257       0.20   -0.072         320.38             Low  2011      akki
# 451       0.50  -58.560         109.14            High  2011      akki
# 625       0.25 -172.125         128.01             Low  2011      akki
# 626       0.35 -456.174         118.63             Low  2011      akki
# ...        ...      ...            ...             ...   ...       ...
# 50781     0.00    0.000         121.83             Low  2014      akki
# 50969     0.20 -200.080         120.11            High  2014      akki
# 50970     0.10  -44.940         108.27             Low  2014      akki
# 51034     0.10 -102.411         255.42          Medium  2014      akki
# 51153     0.40 -166.470         124.63        Critical  2014      akki
#
# [604 rows x 22 columns]

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# category1          object
# dtype: object

# %%
date = pd.to_datetime(df['order_date'])

# %%
date
# Out:
# 0       2011-01-01
# 1       2011-01-01
# 2       2011-01-01
# 3       2011-01-01
# 4       2011-01-01
#            ...
# 51285   2014-12-31
# 51286   2014-12-31
# 51287   2014-12-31
# 51288   2014-12-31
# 51289   2014-12-31
# Name: order_date, Length: 51290, dtype: datetime64[ns]

# %%
type(date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df [ 'convert_to_date'] = pd.to_datetime(df['order_date'])

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 1           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region  ...                                     product_name sales  \
# 0       Africa  ...                              Tenex Lockers, Blue   408
# 1      Oceania  ...                         Acme Trimmer, High Speed   120
# 2         EMEA  ...                          Tenex Box, Single Width    66
# 3        North  ...                      Enermax Note Cards, Premium    45
# 4      Oceania  ...                       Eldon Light Bulb, Duo Pack   114
# ...        ...  ...                                              ...   ...
# 51285     West  ...  Cardinal Slant-D Ring Binder, Heavy Gauge Vinyl    14
# 51286   Africa  ...          Wilson Jones Hole Reinforcements, Clear     4
# 51287  Central  ...           Hon Color Coded Labels, 5000 Label Set    26
# 51288    North  ...           Hon Legal Exhibit Labels, Alphabetical     7
# 51289     West  ...                              Bagged Rubber Bands     3
#
#       quantity discount    profit  shipping_cost  order_priority  year  \
# 0            2      0.0  106.1400          35.46          Medium  2011
# 1            3      0.1   36.0360           9.72          Medium  2011
# 2            4      0.0   29.6400           8.17            High  2011
# 3            3      0.5  -26.0550           4.82            High  2011
# 4            5      0.1   37.7700           4.70          Medium  2011
# ...        ...      ...       ...            ...             ...   ...
# 51285        2      0.2    4.5188           0.89          Medium  2014
# 51286        1      0.0    0.4200           0.49          Medium  2014
# 51287        3      0.0   12.3600           0.35          Medium  2014
# 51288        1      0.0    0.5600           0.20          Medium  2014
# 51289        3      0.2   -0.6048           0.17          Medium  2014
#
#        category1 convert_to_date
# 0           akki      2011-01-01
# 1           akki      2011-01-01
# 2           akki      2011-01-01
# 3           akki      2011-01-01
# 4           akki      2011-01-01
# ...          ...             ...
# 51285       akki      2014-12-31
# 51286       akki      2014-12-31
# 51287       akki      2014-12-31
# 51288       akki      2014-12-31
# 51289       akki      2014-12-31
#
# [51290 rows x 23 columns]

# %%
df['order_date_year'] = df['convert_to_date'].dt.year

# %%
df['month'] = df['convert_to_date'].dt.month

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 1           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region  ... quantity discount    profit shipping_cost order_priority  \
# 0       Africa  ...        2      0.0  106.1400         35.46         Medium
# 1      Oceania  ...        3      0.1   36.0360          9.72         Medium
# 2         EMEA  ...        4      0.0   29.6400          8.17           High
# 3        North  ...        3      0.5  -26.0550          4.82           High
# 4      Oceania  ...        5      0.1   37.7700          4.70         Medium
# ...        ...  ...      ...      ...       ...           ...            ...
# 51285     West  ...        2      0.2    4.5188          0.89         Medium
# 51286   Africa  ...        1      0.0    0.4200          0.49         Medium
# 51287  Central  ...        3      0.0   12.3600          0.35         Medium
# 51288    North  ...        1      0.0    0.5600          0.20         Medium
# 51289     West  ...        3      0.2   -0.6048          0.17         Medium
#
#        year  category1  convert_to_date  order_date_year month
# 0      2011       akki       2011-01-01             2011     1
# 1      2011       akki       2011-01-01             2011     1
# 2      2011       akki       2011-01-01             2011     1
# 3      2011       akki       2011-01-01             2011     1
# 4      2011       akki       2011-01-01             2011     1
# ...     ...        ...              ...              ...   ...
# 51285  2014       akki       2014-12-31             2014    12
# 51286  2014       akki       2014-12-31             2014    12
# 51287  2014       akki       2014-12-31             2014    12
# 51288  2014       akki       2014-12-31             2014    12
# 51289  2014       akki       2014-12-31             2014    12
#
# [51290 rows x 25 columns]

# %%
df['weak'] = df['convert_to_date'].dt.week
# Out:
# C:\Users\91932\AppData\Local\Temp\ipykernel_10888\1014765330.py:1: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated. Please use Series.dt.isocalendar().week instead.
#   df['weak'] = df['convert_to_date'].dt.week

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ... discount  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...      0.0
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...      0.0
# 3  Home Office        Stockholm     Sweden      EU    North  ...      0.5
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...      0.1
#
#     profit shipping_cost order_priority  year  category1  convert_to_date  \
# 0  106.140         35.46         Medium  2011       akki       2011-01-01
# 1   36.036          9.72         Medium  2011       akki       2011-01-01
# 2   29.640          8.17           High  2011       akki       2011-01-01
# 3  -26.055          4.82           High  2011       akki       2011-01-01
# 4   37.770          4.70         Medium  2011       akki       2011-01-01
#
#    order_date_year  month weak
# 0             2011      1   52
# 1             2011      1   52
# 2             2011      1   52
# 3             2011      1   52
# 4             2011      1   52
#
# [5 rows x 26 columns]

# %%
df[['order_date_year', 'weak']]
# Out:
#        order_date_year  weak
# 0                 2011    52
# 1                 2011    52
# 2                 2011    52
# 3                 2011    52
# 4                 2011    52
# ...                ...   ...
# 51285             2014     1
# 51286             2014     1
# 51287             2014     1
# 51288             2014     1
# 51289             2014     1
#
# [51290 rows x 2 columns]

# %%
df[df['order_date_year'] == 2014]
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 33759  ES-2014-2774938    1/1/2014  1/3/2014    Second Class
# 33760    IN-2014-47134    1/1/2014  1/5/2014  Standard Class
# 33761  IT-2014-4810734    1/1/2014  1/3/2014    Second Class
# 33762   US-2014-105830    1/1/2014  1/3/2014     First Class
# 33763   CA-2014-160395    1/1/2014  1/7/2014  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name    segment             state        country  market  \
# 33759       Fred Harton   Consumer     Ile-de-France         France      EU
# 33760       Kean Nguyen  Corporate          Victoria      Australia    APAC
# 33761      Alan Shonely   Consumer     Ile-de-France         France      EU
# 33762      Duane Benoit   Consumer              Ohio  United States      US
# 33763     Kelly Lampkin  Corporate            Nevada  United States      US
# ...                 ...        ...               ...            ...     ...
# 51285        Erica Bern  Corporate        California  United States      US
# 51286         Liz Preis   Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton   Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen   Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias   Consumer          Colorado  United States      US
#
#         region  ... discount    profit shipping_cost order_priority  year  \
# 33759  Central  ...     0.15 -111.6225        104.69           High  2014
# 33760  Oceania  ...     0.10   46.9980         46.20         Medium  2014
# 33761  Central  ...     0.15  -43.1370         37.85       Critical  2014
# 33762     East  ...     0.20  -35.2152         30.66           High  2014
# 33763     West  ...     0.20   53.9217         26.90            Low  2014
# ...        ...  ...      ...       ...           ...            ...   ...
# 51285     West  ...     0.20    4.5188          0.89         Medium  2014
# 51286   Africa  ...     0.00    0.4200          0.49         Medium  2014
# 51287  Central  ...     0.00   12.3600          0.35         Medium  2014
# 51288    North  ...     0.00    0.5600          0.20         Medium  2014
# 51289     West  ...     0.20   -0.6048          0.17         Medium  2014
#
#        category1  convert_to_date  order_date_year  month weak
# 33759       akki       2014-01-01             2014      1    1
# 33760       akki       2014-01-01             2014      1    1
# 33761       akki       2014-01-01             2014      1    1
# 33762       akki       2014-01-01             2014      1    1
# 33763       akki       2014-01-01             2014      1    1
# ...          ...              ...              ...    ...  ...
# 51285       akki       2014-12-31             2014     12    1
# 51286       akki       2014-12-31             2014     12    1
# 51287       akki       2014-12-31             2014     12    1
# 51288       akki       2014-12-31             2014     12    1
# 51289       akki       2014-12-31             2014     12    1
#
# [17531 rows x 26 columns]

# %%
df[df['order_date_year'] == 2014]
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 33759  ES-2014-2774938    1/1/2014  1/3/2014    Second Class
# 33760    IN-2014-47134    1/1/2014  1/5/2014  Standard Class
# 33761  IT-2014-4810734    1/1/2014  1/3/2014    Second Class
# 33762   US-2014-105830    1/1/2014  1/3/2014     First Class
# 33763   CA-2014-160395    1/1/2014  1/7/2014  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name    segment             state        country  market  \
# 33759       Fred Harton   Consumer     Ile-de-France         France      EU
# 33760       Kean Nguyen  Corporate          Victoria      Australia    APAC
# 33761      Alan Shonely   Consumer     Ile-de-France         France      EU
# 33762      Duane Benoit   Consumer              Ohio  United States      US
# 33763     Kelly Lampkin  Corporate            Nevada  United States      US
# ...                 ...        ...               ...            ...     ...
# 51285        Erica Bern  Corporate        California  United States      US
# 51286         Liz Preis   Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton   Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen   Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias   Consumer          Colorado  United States      US
#
#         region  ... discount    profit shipping_cost order_priority  year  \
# 33759  Central  ...     0.15 -111.6225        104.69           High  2014
# 33760  Oceania  ...     0.10   46.9980         46.20         Medium  2014
# 33761  Central  ...     0.15  -43.1370         37.85       Critical  2014
# 33762     East  ...     0.20  -35.2152         30.66           High  2014
# 33763     West  ...     0.20   53.9217         26.90            Low  2014
# ...        ...  ...      ...       ...           ...            ...   ...
# 51285     West  ...     0.20    4.5188          0.89         Medium  2014
# 51286   Africa  ...     0.00    0.4200          0.49         Medium  2014
# 51287  Central  ...     0.00   12.3600          0.35         Medium  2014
# 51288    North  ...     0.00    0.5600          0.20         Medium  2014
# 51289     West  ...     0.20   -0.6048          0.17         Medium  2014
#
#        category1  convert_to_date  order_date_year  month weak
# 33759       akki       2014-01-01             2014      1    1
# 33760       akki       2014-01-01             2014      1    1
# 33761       akki       2014-01-01             2014      1    1
# 33762       akki       2014-01-01             2014      1    1
# 33763       akki       2014-01-01             2014      1    1
# ...          ...              ...              ...    ...  ...
# 51285       akki       2014-12-31             2014     12    1
# 51286       akki       2014-12-31             2014     12    1
# 51287       akki       2014-12-31             2014     12    1
# 51288       akki       2014-12-31             2014     12    1
# 51289       akki       2014-12-31             2014     12    1
#
# [17531 rows x 26 columns]

# %%
df['month'].value_counts()
# Out:
# 11    6342
# 12    6302
# 9     5975
# 6     5331
# 8     5078
# 10    4490
# 5     3747
# 7     3166
# 4     3057
# 3     3035
# 1     2599
# 2     2168
# Name: month, dtype: int64

# %%
df['cost_to_company'] = df['discount'] + df['shipping_cost']

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...  \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#   shipping_cost order_priority  year category1 convert_to_date  \
# 0         35.46         Medium  2011      akki      2011-01-01
# 1          9.72         Medium  2011      akki      2011-01-01
# 2          8.17           High  2011      akki      2011-01-01
# 3          4.82           High  2011      akki      2011-01-01
# 4          4.70         Medium  2011      akki      2011-01-01
#
#    order_date_year  month  weak  cost_to_compoa cost_to_company
# 0             2011      1    52           35.46           35.46
# 1             2011      1    52            9.82            9.82
# 2             2011      1    52            8.17            8.17
# 3             2011      1    52            5.32            5.32
# 4             2011      1    52            4.80            4.80
#
# [5 rows x 28 columns]

# %%
df[df['cost_to_company'] == min(df['cost_to_company'])]['product_name']
# Out:
# 9827                     Acco Index Tab, Economy
# 11846    Eaton Computer Printout Paper, 8.5 x 11
# Name: product_name, dtype: object

# %%
df.drop('cost_to_company', axis = 1)
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 1           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region  ...    profit shipping_cost order_priority  year category1  \
# 0       Africa  ...  106.1400         35.46         Medium  2011      akki
# 1      Oceania  ...   36.0360          9.72         Medium  2011      akki
# 2         EMEA  ...   29.6400          8.17           High  2011      akki
# 3        North  ...  -26.0550          4.82           High  2011      akki
# 4      Oceania  ...   37.7700          4.70         Medium  2011      akki
# ...        ...  ...       ...           ...            ...   ...       ...
# 51285     West  ...    4.5188          0.89         Medium  2014      akki
# 51286   Africa  ...    0.4200          0.49         Medium  2014      akki
# 51287  Central  ...   12.3600          0.35         Medium  2014      akki
# 51288    North  ...    0.5600          0.20         Medium  2014      akki
# 51289     West  ...   -0.6048          0.17         Medium  2014      akki
#
#        convert_to_date  order_date_year  month  weak cost_to_compoa
# 0           2011-01-01             2011      1    52          35.46
# 1           2011-01-01             2011      1    52           9.82
# 2           2011-01-01             2011      1    52           8.17
# 3           2011-01-01             2011      1    52           5.32
# 4           2011-01-01             2011      1    52           4.80
# ...                ...              ...    ...   ...            ...
# 51285       2014-12-31             2014     12     1           1.09
# 51286       2014-12-31             2014     12     1           0.49
# 51287       2014-12-31             2014     12     1           0.35
# 51288       2014-12-31             2014     12     1           0.20
# 51289       2014-12-31             2014     12     1           0.37
#
# [51290 rows x 27 columns]

# %%
df.drop('cost_to_company', axis = 1 , inplace = True)

# %%
df
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 1           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region  ...    profit shipping_cost order_priority  year category1  \
# 0       Africa  ...  106.1400         35.46         Medium  2011      akki
# 1      Oceania  ...   36.0360          9.72         Medium  2011      akki
# 2         EMEA  ...   29.6400          8.17           High  2011      akki
# 3        North  ...  -26.0550          4.82           High  2011      akki
# 4      Oceania  ...   37.7700          4.70         Medium  2011      akki
# ...        ...  ...       ...           ...            ...   ...       ...
# 51285     West  ...    4.5188          0.89         Medium  2014      akki
# 51286   Africa  ...    0.4200          0.49         Medium  2014      akki
# 51287  Central  ...   12.3600          0.35         Medium  2014      akki
# 51288    North  ...    0.5600          0.20         Medium  2014      akki
# 51289     West  ...   -0.6048          0.17         Medium  2014      akki
#
#        convert_to_date  order_date_year  month  weak cost_to_compoa
# 0           2011-01-01             2011      1    52          35.46
# 1           2011-01-01             2011      1    52           9.82
# 2           2011-01-01             2011      1    52           8.17
# 3           2011-01-01             2011      1    52           5.32
# 4           2011-01-01             2011      1    52           4.80
# ...                ...              ...    ...   ...            ...
# 51285       2014-12-31             2014     12     1           1.09
# 51286       2014-12-31             2014     12     1           0.49
# 51287       2014-12-31             2014     12     1           0.35
# 51288       2014-12-31             2014     12     1           0.20
# 51289       2014-12-31             2014     12     1           0.37
#
# [51290 rows x 27 columns]

# %%
df.drop(1)
# Out:
#               order_id  order_date ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011  1/6/2011  Standard Class
# 2         HU-2011-1220    1/1/2011  1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011  1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011  1/8/2011  Standard Class
# ...                ...         ...       ...             ...
# 51285   CA-2014-115427  12/31/2014  1/4/2015  Standard Class
# 51286     MO-2014-2560  12/31/2014  1/5/2015  Standard Class
# 51287   MX-2014-110527  12/31/2014  1/2/2015    Second Class
# 51288   MX-2014-114783  12/31/2014  1/6/2015  Standard Class
# 51289   CA-2014-156720  12/31/2014  1/4/2015  Standard Class
#
#           customer_name      segment             state        country  market  \
# 0       Toby Braunhardt     Consumer       Constantine        Algeria  Africa
# 2         Annie Thurman     Consumer          Budapest        Hungary    EMEA
# 3          Eugene Moren  Home Office         Stockholm         Sweden      EU
# 4           Joseph Holt     Consumer   New South Wales      Australia    APAC
# 5           Joseph Holt     Consumer   New South Wales      Australia    APAC
# ...                 ...          ...               ...            ...     ...
# 51285        Erica Bern    Corporate        California  United States      US
# 51286         Liz Preis     Consumer  Souss-Massa-Dra        Morocco  Africa
# 51287  Charlotte Melton     Consumer           Managua      Nicaragua   LATAM
# 51288     Tamara Dahlen     Consumer         Chihuahua         Mexico   LATAM
# 51289     Jill Matthias     Consumer          Colorado  United States      US
#
#         region  ...    profit shipping_cost order_priority  year category1  \
# 0       Africa  ...  106.1400         35.46         Medium  2011      akki
# 2         EMEA  ...   29.6400          8.17           High  2011      akki
# 3        North  ...  -26.0550          4.82           High  2011      akki
# 4      Oceania  ...   37.7700          4.70         Medium  2011      akki
# 5      Oceania  ...   15.3420          1.80         Medium  2011      akki
# ...        ...  ...       ...           ...            ...   ...       ...
# 51285     West  ...    4.5188          0.89         Medium  2014      akki
# 51286   Africa  ...    0.4200          0.49         Medium  2014      akki
# 51287  Central  ...   12.3600          0.35         Medium  2014      akki
# 51288    North  ...    0.5600          0.20         Medium  2014      akki
# 51289     West  ...   -0.6048          0.17         Medium  2014      akki
#
#        convert_to_date  order_date_year  month  weak cost_to_compoa
# 0           2011-01-01             2011      1    52          35.46
# 2           2011-01-01             2011      1    52           8.17
# 3           2011-01-01             2011      1    52           5.32
# 4           2011-01-01             2011      1    52           4.80
# 5           2011-01-01             2011      1    52           1.90
# ...                ...              ...    ...   ...            ...
# 51285       2014-12-31             2014     12     1           1.09
# 51286       2014-12-31             2014     12     1           0.49
# 51287       2014-12-31             2014     12     1           0.35
# 51288       2014-12-31             2014     12     1           0.20
# 51289       2014-12-31             2014     12     1           0.37
#
# [51289 rows x 27 columns]

# %%
df.loc[1:4]
# Out:
#           order_id order_date ship_date       ship_mode  customer_name  \
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class    Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class  Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class   Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class    Joseph Holt
#
#        segment            state    country market   region  ...  profit  \
# 1     Consumer  New South Wales  Australia   APAC  Oceania  ...  36.036
# 2     Consumer         Budapest    Hungary   EMEA     EMEA  ...  29.640
# 3  Home Office        Stockholm     Sweden     EU    North  ... -26.055
# 4     Consumer  New South Wales  Australia   APAC  Oceania  ...  37.770
#
#   shipping_cost order_priority  year category1  convert_to_date  \
# 1          9.72         Medium  2011      akki       2011-01-01
# 2          8.17           High  2011      akki       2011-01-01
# 3          4.82           High  2011      akki       2011-01-01
# 4          4.70         Medium  2011      akki       2011-01-01
#
#    order_date_year  month  weak cost_to_compoa
# 1             2011      1    52           9.82
# 2             2011      1    52           8.17
# 3             2011      1    52           5.32
# 4             2011      1    52           4.80
#
# [4 rows x 27 columns]

# %%
df[2:10]
# Out:
#           order_id order_date ship_date       ship_mode     customer_name  \
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class     Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class      Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 5    IN-2011-47883   1/1/2011  1/8/2011  Standard Class       Joseph Holt
# 6     CA-2011-1510   1/2/2011  1/6/2011  Standard Class   Magdelene Morse
# 7    IN-2011-79397   1/3/2011  1/3/2011        Same Day       Kean Nguyen
# 8    ID-2011-80230   1/3/2011  1/9/2011  Standard Class      Ken Lonsdale
# 9     IZ-2011-4680   1/3/2011  1/7/2011  Standard Class  Lindsay Williams
#
#        segment            state      country  market   region  ...   profit  \
# 2     Consumer         Budapest      Hungary    EMEA     EMEA  ...   29.640
# 3  Home Office        Stockholm       Sweden      EU    North  ...  -26.055
# 4     Consumer  New South Wales    Australia    APAC  Oceania  ...   37.770
# 5     Consumer  New South Wales    Australia    APAC  Oceania  ...   15.342
# 6     Consumer          Ontario       Canada  Canada   Canada  ...    3.120
# 7    Corporate  New South Wales    Australia    APAC  Oceania  ...  110.412
# 8     Consumer         Auckland  New Zealand    APAC  Oceania  ... -319.464
# 9    Corporate           Ninawa         Iraq    EMEA     EMEA  ...  253.320
#
#   shipping_cost order_priority  year category1  convert_to_date  \
# 2          8.17           High  2011      akki       2011-01-01
# 3          4.82           High  2011      akki       2011-01-01
# 4          4.70         Medium  2011      akki       2011-01-01
# 5          1.80         Medium  2011      akki       2011-01-01
# 6         24.10         Medium  2011      akki       2011-01-02
# 7        125.32       Critical  2011      akki       2011-01-03
# 8        107.10            Low  2011      akki       2011-01-03
# 9         81.26           High  2011      akki       2011-01-03
#
#    order_date_year  month  weak cost_to_compoa
# 2             2011      1    52           8.17
# 3             2011      1    52           5.32
# 4             2011      1    52           4.80
# 5             2011      1    52           1.90
# 6             2011      1    52          24.10
# 7             2011      1     1         125.42
# 8             2011      1     1         107.50
# 9             2011      1     1          81.26
#
# [8 rows x 27 columns]

# %%
df.iloc[0:4, 2:5]
# Out:
#   ship_date       ship_mode    customer_name
# 0  1/6/2011  Standard Class  Toby Braunhardt
# 1  1/8/2011  Standard Class      Joseph Holt
# 2  1/5/2011    Second Class    Annie Thurman
# 3  1/5/2011    Second Class     Eugene Moren

# %%
df.loc[0:14,['ship_date', 'customer_name', 'country']]
# Out:
#    ship_date      customer_name         country
# 0   1/6/2011    Toby Braunhardt         Algeria
# 1   1/8/2011        Joseph Holt       Australia
# 2   1/5/2011      Annie Thurman         Hungary
# 3   1/5/2011       Eugene Moren          Sweden
# 4   1/8/2011        Joseph Holt       Australia
# 5   1/8/2011        Joseph Holt       Australia
# 6   1/6/2011    Magdelene Morse          Canada
# 7   1/3/2011        Kean Nguyen       Australia
# 8   1/9/2011       Ken Lonsdale     New Zealand
# 9   1/7/2011   Lindsay Williams            Iraq
# 10  1/7/2011       Larry Blacks     Philippines
# 11  1/7/2011       Larry Blacks     Philippines
# 12  1/7/2011  Dorothy Dickinson  United Kingdom
# 13  1/9/2011      Dennis Pardue        Malaysia
# 14  1/9/2011       Ken Lonsdale     New Zealand

# %%
df.iloc[0:4,1:4]
# Out:
#   order_date ship_date       ship_mode
# 0   1/1/2011  1/6/2011  Standard Class
# 1   1/1/2011  1/8/2011  Standard Class
# 2   1/1/2011  1/5/2011    Second Class
# 3   1/1/2011  1/5/2011    Second Class

# %%
df.dtypes
# Out:
# order_id                   object
# order_date                 object
# ship_date                  object
# ship_mode                  object
# customer_name              object
# segment                    object
# state                      object
# country                    object
# market                     object
# region                     object
# product_id                 object
# category                   object
# sub_category               object
# product_name               object
# sales                      object
# quantity                    int64
# discount                  float64
# profit                    float64
# shipping_cost             float64
# order_priority             object
# year                        int64
# category1                  object
# convert_to_date    datetime64[ns]
# order_date_year             int64
# month                       int64
# weak                        int64
# cost_to_compoa            float64
# dtype: object

# %%
df.dtypes[(df.dtypes == 'float64') | (df.dtypes == 'int64')]
# Out:
# quantity             int64
# discount           float64
# profit             float64
# shipping_cost      float64
# year                 int64
# order_date_year      int64
# month                int64
# weak                 int64
# cost_to_compoa     float64
# dtype: object

# %%
df2 = df[df.dtypes[(df.dtypes == 'float64') | (df.dtypes == 'int64')].index]

# %%
df3 =df2[df2>100]

# %%
df2.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year  \
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000
#
#        order_date_year         month          weak  cost_to_compoa
# count     51290.000000  51290.000000  51290.000000    51290.000000
# mean       2012.777208      7.522636     30.675687       26.518823
# std           1.098931      3.300056     14.535168       57.280413
# min        2011.000000      1.000000      1.000000        0.000000
# 25%        2012.000000      5.000000     20.000000        2.780000
# 50%        2013.000000      8.000000     33.000000        7.920000
# 75%        2014.000000     10.000000     44.000000       24.577500
# max        2014.000000     12.000000     52.000000      933.570000

# %%
df3
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           NaN       NaN  106.14            NaN  2011             2011
# 1           NaN       NaN     NaN            NaN  2011             2011
# 2           NaN       NaN     NaN            NaN  2011             2011
# 3           NaN       NaN     NaN            NaN  2011             2011
# 4           NaN       NaN     NaN            NaN  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       NaN       NaN     NaN            NaN  2014             2014
# 51286       NaN       NaN     NaN            NaN  2014             2014
# 51287       NaN       NaN     NaN            NaN  2014             2014
# 51288       NaN       NaN     NaN            NaN  2014             2014
# 51289       NaN       NaN     NaN            NaN  2014             2014
#
#        month  weak  cost_to_compoa
# 0        NaN   NaN             NaN
# 1        NaN   NaN             NaN
# 2        NaN   NaN             NaN
# 3        NaN   NaN             NaN
# 4        NaN   NaN             NaN
# ...      ...   ...             ...
# 51285    NaN   NaN             NaN
# 51286    NaN   NaN             NaN
# 51287    NaN   NaN             NaN
# 51288    NaN   NaN             NaN
# 51289    NaN   NaN             NaN
#
# [51290 rows x 9 columns]

# %%
df3.dropna()
# Out:
# Empty DataFrame
# Columns: [quantity, discount, profit, shipping_cost, year, order_date_year, month, weak, cost_to_compoa]
# Index: []

# %%
df3.dropna(thresh=3)
# Out:
#        quantity  discount   profit  shipping_cost  year  order_date_year  \
# 0           NaN       NaN  106.140            NaN  2011             2011
# 7           NaN       NaN  110.412         125.32  2011             2011
# 8           NaN       NaN      NaN         107.10  2011             2011
# 9           NaN       NaN  253.320            NaN  2011             2011
# 12          NaN       NaN  290.430            NaN  2011             2011
# ...         ...       ...      ...            ...   ...              ...
# 51234       NaN       NaN  216.720            NaN  2014             2014
# 51236       NaN       NaN  180.240            NaN  2014             2014
# 51245       NaN       NaN  105.000            NaN  2014             2014
# 51252       NaN       NaN  166.440            NaN  2014             2014
# 51269       NaN       NaN  153.090            NaN  2014             2014
#
#        month  weak  cost_to_compoa
# 0        NaN   NaN             NaN
# 7        NaN   NaN          125.42
# 8        NaN   NaN          107.50
# 9        NaN   NaN             NaN
# 12       NaN   NaN             NaN
# ...      ...   ...             ...
# 51234    NaN   NaN             NaN
# 51236    NaN   NaN             NaN
# 51245    NaN   NaN             NaN
# 51252    NaN   NaN             NaN
# 51269    NaN   NaN             NaN
#
# [6823 rows x 9 columns]

# %%
df3.fillna(value= 5)
# Out:
#        quantity  discount  profit  shipping_cost  year  order_date_year  \
# 0           5.0       5.0  106.14            5.0  2011             2011
# 1           5.0       5.0    5.00            5.0  2011             2011
# 2           5.0       5.0    5.00            5.0  2011             2011
# 3           5.0       5.0    5.00            5.0  2011             2011
# 4           5.0       5.0    5.00            5.0  2011             2011
# ...         ...       ...     ...            ...   ...              ...
# 51285       5.0       5.0    5.00            5.0  2014             2014
# 51286       5.0       5.0    5.00            5.0  2014             2014
# 51287       5.0       5.0    5.00            5.0  2014             2014
# 51288       5.0       5.0    5.00            5.0  2014             2014
# 51289       5.0       5.0    5.00            5.0  2014             2014
#
#        month  weak  cost_to_compoa
# 0        5.0   5.0             5.0
# 1        5.0   5.0             5.0
# 2        5.0   5.0             5.0
# 3        5.0   5.0             5.0
# 4        5.0   5.0             5.0
# ...      ...   ...             ...
# 51285    5.0   5.0             5.0
# 51286    5.0   5.0             5.0
# 51287    5.0   5.0             5.0
# 51288    5.0   5.0             5.0
# 51289    5.0   5.0             5.0
#
# [51290 rows x 9 columns]

# %%
df3.fillna(value= df3['profit'].mean())
# Out:
#          quantity    discount      profit  shipping_cost  year  \
# 0      285.710477  285.710477  106.140000     285.710477  2011
# 1      285.710477  285.710477  285.710477     285.710477  2011
# 2      285.710477  285.710477  285.710477     285.710477  2011
# 3      285.710477  285.710477  285.710477     285.710477  2011
# 4      285.710477  285.710477  285.710477     285.710477  2011
# ...           ...         ...         ...            ...   ...
# 51285  285.710477  285.710477  285.710477     285.710477  2014
# 51286  285.710477  285.710477  285.710477     285.710477  2014
# 51287  285.710477  285.710477  285.710477     285.710477  2014
# 51288  285.710477  285.710477  285.710477     285.710477  2014
# 51289  285.710477  285.710477  285.710477     285.710477  2014
#
#        order_date_year       month        weak  cost_to_compoa
# 0                 2011  285.710477  285.710477      285.710477
# 1                 2011  285.710477  285.710477      285.710477
# 2                 2011  285.710477  285.710477      285.710477
# 3                 2011  285.710477  285.710477      285.710477
# 4                 2011  285.710477  285.710477      285.710477
# ...                ...         ...         ...             ...
# 51285             2014  285.710477  285.710477      285.710477
# 51286             2014  285.710477  285.710477      285.710477
# 51287             2014  285.710477  285.710477      285.710477
# 51288             2014  285.710477  285.710477      285.710477
# 51289             2014  285.710477  285.710477      285.710477
#
# [51290 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1', 'convert_to_date', 'order_date_year', 'month', 'weak',
#        'cost_to_compoa'],
#       dtype='object')

# %%
df.groupby('order_date_year')['profit'].mean()
# Out:
# order_date_year
# 2011    27.666238
# 2012    28.043722
# 2013    29.604519
# 2014    28.758540
# Name: profit, dtype: float64

# %%
df.groupby('order_date_year')['discount'].mean()
# Out:
# order_date_year
# 2011    0.148188
# 2012    0.141286
# 2013    0.140265
# 2014    0.143291
# Name: discount, dtype: float64

# %%
df.groupby('order_date_year')['shipping_cost'].mean()
# Out:
# order_date_year
# 2011    27.147264
# 2012    25.861329
# 2013    26.418577
# 2014    26.268197
# Name: shipping_cost, dtype: float64

# %%
df.groupby('order_date_year')['sales'].count()
# Out:
# order_date_year
# 2011     8998
# 2012    10962
# 2013    13799
# 2014    17531
# Name: sales, dtype: int64

# %%
df['sales'] = df.sales.str.replace(',',"").astype(int)

# %%
df.dtypes
# Out:
# order_id                   object
# order_date                 object
# ship_date                  object
# ship_mode                  object
# customer_name              object
# segment                    object
# state                      object
# country                    object
# market                     object
# region                     object
# product_id                 object
# category                   object
# sub_category               object
# product_name               object
# sales                       int32
# quantity                    int64
# discount                  float64
# profit                    float64
# shipping_cost             float64
# order_priority             object
# year                        int64
# category1                  object
# convert_to_date    datetime64[ns]
# order_date_year             int64
# month                       int64
# weak                        int64
# cost_to_compoa            float64
# dtype: object

# %%
df.groupby('order_date_year')['sales'].mean()
# Out:
# order_date_year
# 2011    251.112581
# 2012    244.252235
# 2013    246.819335
# 2014    245.282129
# Name: sales, dtype: float64
